# %%
import pandas as pd
import numpy as np
import sqlite3
from sqlalchemy import create_engine

database_path = "../usdaplantsapi/usdadb_new.sqlite3"

# %%
conn = sqlite3.connect(f"sqlite:///{database_path}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-43b68d111d02> in <module>
# ----> 1 conn = sqlite3.connect(f"sqlite:///{database_path}")
#
# OperationalError: unable to open database file

# %%
conn = sqlite3.connect('../usdaplantsapi/usdadb_new.sqlite3')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-5bfd50773796> in <module>
# ----> 1 conn = sqlite3.connect('../usdaplantsapi/usdadb_new.sqlite3')
#       2 cursor = conn.cursor()
#       3 cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
#       4 print(cursor.fetchall())
#
# OperationalError: unable to open database file

# %%
c = conn.cursor()

# %%
data = pd.read_sql("SELECT * FROM usda", conn)

# %%
data
# Out:
#           id  Symbol Accepted_Symbol_x Synonym_Symbol_x  \
# 0          1    ABAB              ABAB
# 1          2   ABAB2             ABPR3            ABAB2
# 2          3   ABAB3              ABTH            ABAB3
# 3          4  ABAB70            ABAB70
# 4          5    ABAC             ABUMB             ABAC
# ...      ...     ...               ...              ...
# 92166  92167   ZYVIR             ZYVIR
# 92167  92168  ZYVIR2             ZYVIR           ZYVIR2
# 92168  92169   ZYVIV             ZYVIV
# 92169  92170  ZYVIV2             ZYVIR           ZYVIV2
# 92170  92171    ZYVU             ZYVIR             ZYVU
#
#                                        Scientific_Name_x  \
# 0          Abutilon abutiloides (Jacq.) Garcke ex Hochr.
# 1                 Abrus abrus (L.) W. Wight, nom. inval.
# 2              Abutilon abutilon (L.) Rusby, nom. inval.
# 3                  Abietinella abietina (Hedw.) Fleisch.
# 4                              Abronia acutalata Standl.
# ...

# %%
plants_df = data.copy()

# %%
plants_df.to_csv(usda_)
