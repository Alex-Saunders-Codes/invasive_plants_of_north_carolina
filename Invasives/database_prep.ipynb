# %%
import pandas as pd

# %%
invasives = pd.read_csv("invasive_locs.csv")
invasives.head()
# Out:
#    Unnamed: 0  Index            Preferred_scientific_name  \
# 0           0      0                   Caulerpa taxifolia
# 1           1      1  Codium fragile subsp. tomentosoides
# 2           2      2                           Ulva ohnoi
# 3           3      3                         Ulva pertusa
# 4           4      4                      Ulva reticulata
#
#   International_common_name ISC_content Plant_pest       _5      Domain  \
# 0              killer algae        Full         No   Plants   Eukaryota
# 1                                  Full         No   Plants   Eukaryota
# 2                                  Full         No   Plants   Eukaryota
# 3                                  Full         No   Plants   Eukaryota
# 4        ribbon sea lettuce        Full         No   Plants   Eukaryota
#
#     Kingdon        Phylum              Class          Order         Family  \
# 0   Plantae   Chlorophyta   Bryopsidophyceae   Bryopsidales   Caulerpaceae
# ...

# %%
locations = [[[plant['Index'], location] for location in plant['present']] for plant in invasives]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2461b5b16a21> in <module>
# ----> 1 locations = [[[plant['Index'], location] for location in plant['present']] for plant in invasives]
#
# <ipython-input-6-2461b5b16a21> in <listcomp>(.0)
# ----> 1 locations = [[[plant['Index'], location] for location in plant['present']] for plant in invasives]
#
# TypeError: string indices must be integers

# %%
invasives['present'][0]
# Out:
# '[\'Cabo Verde\', "Côte d\'Ivoire", \'Equatorial Guinea\', \'Gabon\', \'Gambia\', \'Ghana\', \'Kenya\', \'Madagascar\', \'Mauritania\', \'Mauritius\', \'São Tomé and Príncipe\', \'Senegal\', \'Seychelles\', \'Tanzania\', \'Tunisia\', \'Bangladesh\', \'China\', \'India\', \'-Andaman and Nicobar Islands\', \'Indonesia\', \'Japan\', \'Malaysia\', \'-Sarawak\', \'Maldives\', \'Pakistan\', \'Philippines\', \'Saudi Arabia\', \'Singapore\', \'Sri Lanka\', \'Thailand\', \'Vietnam\', \'Yemen\', \'Croatia\', \'France\', \'Italy\', \'Monaco\', \'Spain\', \'-Balearic Islands\', \'-Canary Islands\', \'Barbados\', \'Belize\', \'Bermuda\', \'Cuba\', \'Jamaica\', \'Mexico\', \'Netherlands Antilles\', \'Panama\', \'Puerto Rico\', \'Trinidad and Tobago\', \'U.S. Virgin Islands\', \'United States\', \'-California\', \'-Hawaii\', \'American Samoa\', \'Australia\', \'-Lord Howe Island\', \'-New South Wales\', \'-Northern Territory\', \'-Queensland\', \'-South Australia\', \'-Western Australia\', \'Federa
# ...

# %%
locations = [[location for location in plant.replace("\"","").replace("\"","").replace("\'","").replace("[", "").replace("]", "").split(", ")] for plant in invasives['present']]

# %%
len(locations)
# Out:
# 1016

# %%
list_splits = invasives['present'][0]

# %%
example = list_splits.replace("\"","").replace("\"","").replace("\'","").replace("[", "").replace("]", "").split(", ")
                                    #.split(",")

# %%
remove_dash = [[location for location in plant if "-" not in location] for plant in locations]

# %%
to_db = [[i ,country] for i in range(len(remove_dash)) for country in remove_dash[i]]

# %%
to_db[0:10]
# Out:
# [[0, 'Cabo Verde'],
#  [0, 'Côte dIvoire'],
#  [0, 'Equatorial Guinea'],
#  [0, 'Gabon'],
#  [0, 'Gambia'],
#  [0, 'Ghana'],
#  [0, 'Kenya'],
#  [0, 'Madagascar'],
#  [0, 'Mauritania'],
#  [0, 'Mauritius']]

# %%
country_plant_match = pd.DataFrame(to_db)

# %%
country_plant_match.to_csv('country_plants_match.csv')

# %%
unique_countries = set([country for pair in to_db for country in pair if type(country) is str])
unique_countries
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos Islands',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  'Czechoslovakia',
#  'Côte dIvoire',
#  'Democratic Republic of the',
# ...
